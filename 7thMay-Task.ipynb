# %%
# INTEGER TYPECASTING

# %%
int(1)
# Out:
# 1

# %%
int(20.5)
# Out:
# 20

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(false)
#
# NameError: name 'false' is not defined

# %%
int('1')
# Out:
# 1

# %%
int('15ab')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('15ab')
#
# ValueError: invalid literal for int() with base 10: '15ab'

# %%
int('15b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('15b')
#
# ValueError: invalid literal for int() with base 10: '15b'

# %%
int('15')
# Out:
# 15

# %%
int('ab15')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int('ab15')
#
# ValueError: invalid literal for int() with base 10: 'ab15'

# %%
int('-16')
# Out:
# -16

# %%
int('-20.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 int('-20.5')
#
# ValueError: invalid literal for int() with base 10: '-20.5'

# %%
int('20.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 int('20.4')
#
# ValueError: invalid literal for int() with base 10: '20.4'

# %%
int('True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int('True')
#
# ValueError: invalid literal for int() with base 10: 'True'

# %%
int('False')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 int('False')
#
# ValueError: invalid literal for int() with base 10: 'False'

# %%
# FLOAT TYPECASTING

# %%
float(20)
# Out:
# 20.0

# %%
float('20')
# Out:
# 20.0

# %%
float('-20.3')
# Out:
# -20.3

# %%
float('a20.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 float('a20.4')
#
# ValueError: could not convert string to float: 'a20.4'

# %%
float(False)
# Out:
# 0.0

# %%
float(True)
# Out:
# 1.0

# %%
float('20.66')
# Out:
# 20.66

# %%
# BOOLEAN TYPECASTING

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool('True')
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 bool(a)
#
# NameError: name 'a' is not defined

# %%
# COMPLEX TYPECASTING

# %%
complex(20)
# Out:
# (20+0j)

# %%
complex(20.0)
# Out:
# (20+0j)

# %%
complex(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 complex(None)
#
# TypeError: complex() first argument must be a string or a number, not 'NoneType'

# %%
complex(0)
# Out:
# 0j

# %%
complex(-1)
# Out:
# (-1+0j)

# %% [markdown]
# complex(None, 1)

# %%
complex(-1)
# Out:
# (-1+0j)

# %%
complex('20')
# Out:
# (20+0j)

# %%
complex('Str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 complex('Str')
#
# ValueError: complex() arg is a malformed string

# %%
complex('20', '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 complex('20', '20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(20, '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 complex(20, '20')
#
# TypeError: complex() second arg can't be a string

# %%
complex('20', 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 complex('20', 20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(0, -1)
# Out:
# -1j

# %%
complex(1, None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 complex(1, None)
#
# TypeError: complex() second argument must be a number, not 'NoneType'

# %%
# STRING TYPECASTING

# %%
str(20)
# Out:
# '20'

# %%
str(20.4)
# Out:
# '20.4'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(-1)
# Out:
# '-1'

# %%
str(0.0)
# Out:
# '0.0'

# %%
str(None)
# Out:
# 'None'

# %%
str(' ')
# Out:
# ' '

# %%
str(type(1))
# Out:
# "<class 'int'>"

# %%
# PYTHON OPERATORS

# %%
# ARITHMETIC OPERATOR

# %%
a,b = 10, 8
a + b
# Out:
# 18

# %%
a - b
# Out:
# 2

# %%
a * b
# Out:
# 80

# %%
a/b
# Out:
# 1.25

# %%
a//b
# Out:
# 1

# %%
a = a+b
a
# Out:
# 34

# %%
a += b
a
# Out:
# 50

# %%
a -= b
a
# Out:
# 42

# %%
a *= b
a
# Out:
# 336

# %%
a /= b
a
# Out:
# 42.0

# %%
a //= b
a
# Out:
# 5.0

# %%
a %= b
a
# Out:
# 5.0

# %%
a = 150

# %%
# UNARY OPERATOR

# %%
n = 10
n = -(n)
n
# Out:
# -10

# %%
n = -10
n = -(n)
n
# Out:
# 10

# %%
n = -0
n = -(n)
n
# Out:
# 0

# %%
n = 0
n = -(n)
n
# Out:
# 0

# %%
# RELATIONAL OPERATOR

# %%
1 > 0
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1>1
# Out:
# False

# %%
1>=1
# Out:
# True

# %%
1<2
# Out:
# True

# %%
1<1
# Out:
# False

# %%
1<=1
# Out:
# True

# %%
None <= None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 None <= None
#
# TypeError: '<=' not supported between instances of 'NoneType' and 'NoneType'

# %%
None <= 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 None <= 1
#
# TypeError: '<=' not supported between instances of 'NoneType' and 'int'

# %%
'' <= 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 '' <= 0
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
1 == None
# Out:
# False

# %%
1 == ''
# Out:
# False

# %%
1==0
# Out:
# False

# %%
None == None
# Out:
# True

# %%
None != None
# Out:
# False

# %%
None >= None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 None >= None
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'NoneType'

# %%
# LOGICAL OPERATOR

# %%
 1 > 0 and 1 ==1
# Out:
# True

# %%
1 > 2 and 1==1
# Out:
# False

# %%
1 > None and 2 > 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 1 > None and 2 > 1
#
# TypeError: '>' not supported between instances of 'int' and 'NoneType'

# %%
1 > 2 or 2>1
# Out:
# True

# %%
x=4
y=5
x not y
# Out:
#   Cell In[104], line 3
#     x not y
#           ^
# SyntaxError: invalid syntax
